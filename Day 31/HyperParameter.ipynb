# %% [markdown]
# # All Techniques Of Hyper Parameter Optimization
# 1. GridSearchCV
# 2. RandomizedSearchCV
# 3. Bayesian Optimization -Automate Hyperparameter Tuning (Hyperopt)
# 4. Sequential Model Based Optimization(Tuning a scikit-learn estimator with skopt)
# 5. Optuna- Automate Hyperparameter Tuning
# 6. Genetic Algorithms (TPOT Classifier)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import numpy as np 
df['Glucose']=np.where(df['Glucose']==0,df['Glucose'].median(),df['Glucose'])
df['Insulin']=np.where(df['Insulin']==0,df['Insulin'].median(),df['Insulin'])
df['SkinThickness']=np.where(df['SkinThickness']==0,df['SkinThickness'].median(),df['SkinThickness'])
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72           35.0     30.5  33.6
# 1            1     85.0             66           29.0     30.5  26.6
# 2            8    183.0             64           23.0     30.5  23.3
# 3            1     89.0             66           23.0     94.0  28.1
# 4            0    137.0             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
## Indepedent and Dependent features
X=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
print(X.head())
print(y.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72           35.0     30.5  33.6
# 1            1     85.0             66           29.0     30.5  26.6
# 2            8    183.0             64           23.0     30.5  23.3
# 3            1     89.0             66           23.0     94.0  28.1
# 4            0    137.0             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_text,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=33)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=10).fit(X_train,y_train)
prediction=rf_classifier.predict(X_text)

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print(confusion_matrix(y_test,prediction))
print(accuracy_score(y_test,prediction))
print(classification_report(y_test,prediction))
# Out:
# [[83 16]
#  [29 26]]
# 0.7077922077922078
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79        99
#            1       0.62      0.47      0.54        55
#
#     accuracy                           0.71       154
#    macro avg       0.68      0.66      0.66       154
# weighted avg       0.70      0.71      0.70       154

# %% [markdown]
# #### The main parameters used by a Random Forest Classifier are:
#
# - criterion = the function used to evaluate the quality of a split.
# - max_depth = maximum number of levels allowed in each tree.
# - max_features = maximum number of features considered when splitting a node.
# - min_samples_leaf = minimum number of samples which can be stored in a tree leaf.
# - min_samples_split = minimum number of samples necessary in a node to cause node splitting.
# - n_estimators = number of trees in the ensamble.

# %%
### Manual Hyperparameter Tuning
model=RandomForestClassifier(n_estimators=300,criterion='entropy',max_features='sqrt',min_samples_leaf=10,random_state=100).fit(X_train,y_train)

predictions=model.predict(X_text)

# %%
print(confusion_matrix(y_test,predictions))
print(accuracy_score(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[87 12]
#  [28 27]]
# 0.7402597402597403
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        99
#            1       0.69      0.49      0.57        55
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.68      0.69       154
# weighted avg       0.73      0.74      0.73       154

# %% [markdown]
# ### Randomized Search Cv

# %%
import numpy as np 
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators=[int(x) for x in np.linspace(start=200,stop=2000,num=10)]

# Number of features to consider at every split
max_features=['auto','sqrt','log2']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]

# Create the random grid
random_grid={'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=RandomForestClassifier()
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,random_state=100,n_jobs=-1)

### fit the randomized model
rf_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=1400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=1400; total time=   1.0s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=1400; total time=   1.1s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.6s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.6s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.6s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   1.2s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   1.3s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   1.7s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=600; total time=   0.4s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   1.4s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   1.6s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   1.6s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   1.3s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   1.6s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   1.7s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=1600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=1600; total time=   1.5s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   1.3s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=1600; total time=   1.6s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   0.9s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   1.5s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   1.5s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   1.2s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   0.9s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=1000, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=1000, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=1000, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   0.8s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1200; total time=   0.9s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1200; total time=   0.9s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1200; total time=   1.0s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=1600; total time=   1.3s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=1600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   1.8s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=1600; total time=   1.4s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   1.6s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   1.8s
# [CV] END criterion=gini, max_depth=890, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   1.5s
# [CV] END criterion=gini, max_depth=890, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   1.7s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=800; total time=   0.9s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   2.0s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   2.0s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   2.1s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   1.9s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   0.7s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   0.7s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.6s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   1.2s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   1.3s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   1.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1800; total time=   1.4s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1800; total time=   1.4s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1800; total time=   1.4s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.4s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   1.7s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   1.4s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   1.7s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   1.4s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   1.4s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=1000; total time=   0.8s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=1000; total time=   0.8s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.8s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=1000; total time=   1.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   1.2s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   1.3s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   1.3s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   1.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   1.7s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   1.7s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   2.0s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   2.1s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   2.2s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   1.7s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   1.7s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   2.1s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   2.2s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   2.0s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   1.1s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=   1.9s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   1.2s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.1s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=   1.9s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   1.3s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   0.9s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1600; total time=   1.6s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1600; total time=   1.6s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1600; total time=   1.6s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   1.7s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   1.7s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   1.7s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   1.1s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1200; total time=   1.2s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1200; total time=   1.2s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1200; total time=   1.2s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=1600; total time=   1.5s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=1600; total time=   1.5s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=1600; total time=   1.6s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.8s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.6s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.8s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   1.1s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.8s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   1.7s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1600; total time=   1.1s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1600; total time=   1.1s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1600; total time=   1.0s
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [10, 120, 230, 340, 450,
#                                                       560, 670, 780, 890,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 6,
#  'max_features': 'log2',
#  'max_depth': 450,
#  'criterion': 'entropy'}

# %%
rf_randomcv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=450, max_features='log2',
#                        min_samples_leaf=6, n_estimators=400)

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid.predict(X_text)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[86 13]
#  [25 30]]
# Accuracy Score 0.7532467532467533
# Classification report:               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        99
#            1       0.70      0.55      0.61        55
#
#     accuracy                           0.75       154
#    macro avg       0.74      0.71      0.72       154
# weighted avg       0.75      0.75      0.75       154

# %% [markdown]
# ### GridSearch CV

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 6,
#  'max_features': 'log2',
#  'max_depth': 450,
#  'criterion': 'entropy'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'], 
                         rf_randomcv.best_params_['min_samples_leaf']+2, 
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] - 2,
                          rf_randomcv.best_params_['min_samples_split'] - 1,
                          rf_randomcv.best_params_['min_samples_split'], 
                          rf_randomcv.best_params_['min_samples_split'] +1,
                          rf_randomcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rf_randomcv.best_params_['n_estimators'] - 200, rf_randomcv.best_params_['n_estimators'] - 100, 
                     rf_randomcv.best_params_['n_estimators'], 
                     rf_randomcv.best_params_['n_estimators'] + 100, rf_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'criterion': ['entropy'], 'max_depth': [450], 'max_features': ['log2'], 'min_samples_leaf': [6, 8, 10], 'min_samples_split': [0, 1, 2, 3, 4], 'n_estimators': [200, 300, 400, 500, 600]}

# %%
1*1*1*3*5*5  #no. of iterations
# Out:
# 75

# %%
#### Fit the grid_search to the data
rf=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.8s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=0, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=1, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   0.8s
# ...
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.8s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=200; total time=   0.2s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.6s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=400; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=3, n_estimators=600; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=500; total time=   0.3s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=600; total time=   0.4s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['entropy'], 'max_depth': [450],
#                          'max_features': ['log2'],
#                          'min_samples_leaf': [6, 8, 10],
#                          'min_samples_split': [0, 1, 2, 3, 4],
#                          'n_estimators': [200, 300, 400, 500, 600]},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=450, max_features='log2',
#                        min_samples_leaf=8, n_estimators=600)

# %%
best_grid=grid_search.best_estimator_

# %%
y_pred=best_grid.predict(X_text)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[87 12]
#  [26 29]]
# Accuracy Score 0.7532467532467533
# Classification report:               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82        99
#            1       0.71      0.53      0.60        55
#
#     accuracy                           0.75       154
#    macro avg       0.74      0.70      0.71       154
# weighted avg       0.75      0.75      0.74       154
